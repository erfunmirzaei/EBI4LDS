# %%
# %cd /Users/erfanmirzaei/Projects/EBI4LDS/Codes/spectral_rates/results
# Out:
# /Users/erfanmirzaei/Projects/EBI4LDS/Codes/spectral_rates/results

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "mathtext.fontset": "cm",
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"]
})
import pickle
import kooplearn.kernels

# %%
import pickle

results = pickle.load(open('results.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pickle
# ----> 3 results = pickle.load(open('results.pkl', 'rb'))
#
# ModuleNotFoundError: No module named 'kooplearn.kernels'

# %%
results = pickle.load(open('results.pkl', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = pickle.load(open('results.pkl', 'rb'))
#
# ModuleNotFoundError: No module named 'kooplearn.kernels'

# %%
best_estimator_id = np.argmin(results['avg_bias'])
rmse = results['forecast_rmse']

# %%
results['kernels'][best_estimator_id]
# Out:
# [RBF] length_scale: 0.35

# %%
rmse[best_estimator_id].shape
# Out:
# (100,)

# %%
# %cd /home/novelli/kooplearn_examples/examples/ala2/spectral_rates/reports
fig, ax = plt.subplots(figsize = (4, 3))
ax.plot(np.arange(1, rmse.shape[1] + 1)*0.05, rmse.T, 'k--', lw=0.75, alpha=0.75)
ax.plot(np.arange(1, rmse.shape[1] + 1)*0.05, rmse[best_estimator_id], 'r-', lw=1.5, label='Best estimator')
ax.set_xlabel(r'Forecast horizon [ns]')
ax.set_yscale('log')
ax.set_ylabel('RMSE')
ax.set_ylim(3e-2, 0.3e1)
ax.set_title('Model selection for Alanine Dipeptide')
ax.margins(x=0)
plt.legend(loc = 'upper left', frameon=False)
plt.savefig("figs/ala2_model_selection.png", bbox_inches="tight")
# Out:
# /home/novelli/kooplearn_examples/examples/ala2/spectral_rates/reports
